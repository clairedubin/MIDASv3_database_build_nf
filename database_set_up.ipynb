# %%
import pandas as pd
import random
import os
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ### Download prokaryotic database and info
#
# https://zenodo.org/records/10457006
#
#     VMGC_prokaryote_MAG.info
#
#     VMGC_prokaryote_MAG.tar.gz
#
#     VMGC_prokaryote_SGB.info

# %% [markdown]
# ### Make genomes.tsv file for MIDAS input
#
#
# Needs columns: genome, species, representative, genome_is_representative

# %%
df = pd.read_csv('VMGC_orig_files/VMGC_prokaryote_MAG.info', sep='\t')

# %%
df.head()
# Out:
#             Genome_ID BioSample_ID Collection/isolation_source Type  \
# 0  ERR10897564.mbin.1  ERR10897564                vaginal swab  MAG
# 1  ERR10897570.mbin.1  ERR10897570                vaginal swab  MAG
# 2  ERR10897572.mbin.2  ERR10897572                vaginal swab  MAG
# 3  ERR10897572.mbin.3  ERR10897572                vaginal swab  MAG
# 4  ERR10897573.mbin.4  ERR10897573                vaginal swab  MAG
#
#    Genome_size_(bp)  No._of_contigs  N50_length_(bp)  N90_length_(bp)  \
# 0           1087166              64            21321             9170
# 1            946879              36            35494            16114
# 2            634492             160             4095             2310
# 3           1042602              73            18747             7657
# 4           2066518             406             5736             2674
#
#    Max_length_(bp)  %_GC_content  %_Completeness  %_Contamination  \
# 0           106681         32.47           92.37             0.36
# 1            91025         44.15           69.36             0.05
# 2            18976         32.86           51.82             0.05
# 3            84304         37.32           59.34             0.17
# 4            38890         42.40           75.82             1.43
#
#    Quality_score  Clade_separation_score_(GUNC) Presence_of_5S_rRNA  \
# 0          90.57                           0.00                   Y
# 1          69.11                           0.03                   N
# 2          51.57                           0.00                   Y
# 3          58.49                           0.00                   N
# 4          68.67                           0.00                   N
#
#   Presence_of_16S_rRNA Presence_of_23S_rRNA  No._of_tRNA  Genome_quality  \
# 0                    N                    N           16    high-quality
# 1                    N                    N           14  medium-quality
# 2                    N                    N           12  medium-quality
# 3                    N                    N           16  medium-quality
# 4                    N                    N           16  medium-quality
#
#   Species-level_genomic_bin_(95%_ANI)
# 0                              SGB001
# 1                              SGB020
# 2                              SGB001
# 3                              SGB006
# 4                              SGB014

# %%
len(df['Genome_ID'].unique()), df.shape[0]
# Out:
# (19542, 19542)

# %%
#get representative genomes from SGB file

# %%
sgb = pd.read_csv('VMGC_orig_files/VMGC_prokaryote_SGB.info', sep='\t', index_col=0)

# %%
sgb.shape
# Out:
# (786, 11)

# %%
rep_genomes = sgb['Representative_genome_ID'].to_dict()

# %%
genomes = df[['Genome_ID','Species-level_genomic_bin_(95%_ANI)']]
genomes = genomes.rename(columns={'Genome_ID':'genome', 'Species-level_genomic_bin_(95%_ANI)':'SGB'})
genomes['representative'] = genomes['SGB'].map(rep_genomes)
genomes
# Out:
#                    genome     SGB      representative
# 0      ERR10897564.mbin.1  SGB001  SRR17284223.mbin.1
# 1      ERR10897570.mbin.1  SGB020  ERR10897780.mbin.8
# 2      ERR10897572.mbin.2  SGB001  SRR17284223.mbin.1
# 3      ERR10897572.mbin.3  SGB006     GCF_000162255.1
# 4      ERR10897573.mbin.4  SGB014    P10708985.mbin.1
# ...                   ...     ...                 ...
# 19537   SRR6748217.mbin.3  SGB026  SRR13167550.mbin.1
# 19538   SRR6748218.mbin.1  SGB025        MG238.mbin.3
# 19539   SRR6748219.mbin.1  SGB004  ERR10897722.mbin.1
# 19540     GCF_029101565.1  SGB009     GCF_029101565.1
# 19541     GCF_029101585.1  SGB080     GCF_001552885.1
#
# [19542 rows x 3 columns]

# %%
genomes['genome_is_representative'] = (genomes['genome'] == genomes['representative']).astype(int)

# %%
genomes['genome_is_representative'].sum()
# Out:
# 786

# %%
sp_list = genomes['SGB'].unique()

# %%
#randomly assign 6 digit numbers to species

random.seed(1)
nums = random.sample(range(100000,999999), len(sp_list))

sp_to_nums = {sp_list[i]:nums[i] for i in range(len(sp_list))}

# %%
genomes['species'] = genomes['SGB'].map(sp_to_nums)

# %%
genomes = genomes.set_index('genome')

# %%
genomes.to_csv('VMGC_orig_files/genomes_and_SGBs.csv')

# %%
genomes.drop(columns='SGB').to_csv('VMGC_db/genomes.tsv', sep='\t')

# %% [markdown]
# ### Organize genomes
#
# Needs to be in the format: "cleaned_genomes/species/genome/genome.fna"

# %%
base_dir = 'VMGC_db/cleaned_genomes/'
# !mkdir {base_dir}
# Out:
# mkdir: VMGC_db/cleaned_genomes/: File exists

# %%
fasta_dir='VMGC_orig_files/VMGC_prokaryote_MAG'
fastas = !ls {fasta_dir}

# %%
# !ls VMGC_db/cleaned_genomes
# Out:
# 109652 187277 278624 342081 536396 653259 805810 940775 988598
# 130451 207192 285819 367695 553789 674974 897926 941235 992625
# 134035 223646 320153 447222 595185 696853 927036 956096 994737
# 173875 240891 339874 508744 611554 766234 937223 982633

# %%
moved = []

for f in fastas:
    
    old_path = fasta_dir + f
    
    genome = f.strip('.fa')
    
    if genome not in genomes.index:
        print(genome)
        
    species = genomes.loc[genome]['species']
    
    species_dir = 'VMGC_db/cleaned_genomes/{}/'.format(species)
    genome_dir = species_dir+genome
    new_path = genome_dir + '/' + genome + '.fna'
    
    if not os.path.exists(species_dir):
        
        # !mkdir {species_dir}
        
    # !mkdir {genome_dir}
    # !mv {old_path} {new_path}
# Out:
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1.mbin.1.fa to VMGC_db/cleaned_genomes/927036/MG1.mbin.1/MG1.mbin.1.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1.mbin.2.fa to VMGC_db/cleaned_genomes/653259/MG1.mbin.2/MG1.mbin.2.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1.mbin.4.fa to VMGC_db/cleaned_genomes/696853/MG1.mbin.4/MG1.mbin.4.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG10.mbin.1.fa to VMGC_db/cleaned_genomes/240891/MG10.mbin.1/MG10.mbin.1.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG10.mbin.2.fa to VMGC_db/cleaned_genomes/223646/MG10.mbin.2/MG10.mbin.2.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG10.mbin.3.fa to VMGC_db/cleaned_genomes/696853/MG10.mbin.3/MG10.mbin.3.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG10.sbin.5.fa to VMGC_db/cleaned_genomes/342081/MG10.sbin.5/MG10.sbin.5.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.mbin.1.fa to VMGC_db/cleaned_genomes/109652/MG100.mbin.1/MG100.mbin.1.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.mbin.10.fa to VMGC_db/cleaned_genomes/992625/MG100.mbin.10/MG100.mbin.10.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.mbin.11.fa to VMGC_db/cleaned_genomes/223646/MG100.mbin.11/MG100.mbin.11.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.mbin.13.fa to VMGC_db/cleaned_genomes/766234/MG100.mbin.13/MG100.mbin.13.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.mbin.15.fa to VMGC_db/cleaned_genomes/611554/MG100.mbin.15/MG100.mbin.15.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.mbin.2.fa to VMGC_db/cleaned_genomes/339874/MG100.mbin.2/MG100.mbin.2.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.mbin.3.fa to VMGC_db/cleaned_genomes/956096/MG100.mbin.3/MG100.mbin.3.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.mbin.4.fa to VMGC_db/cleaned_genomes/367695/MG100.mbin.4/MG100.mbin.4.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.mbin.5.fa to VMGC_db/cleaned_genomes/447222/MG100.mbin.5/MG100.mbin.5.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.mbin.6.fa to VMGC_db/cleaned_genomes/207192/MG100.mbin.6/MG100.mbin.6.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.sbin.12.fa to VMGC_db/cleaned_genomes/367695/MG100.sbin.12/MG100.sbin.12.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.sbin.16.fa to VMGC_db/cleaned_genomes/278624/MG100.sbin.16/MG100.sbin.16.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG100.sbin.5.fa to VMGC_db/cleaned_genomes/897926/MG100.sbin.5/MG100.sbin.5.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1001.mbin.1.fa to VMGC_db/cleaned_genomes/897926/MG1001.mbin.1/MG1001.mbin.1.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1001.mbin.2.fa to VMGC_db/cleaned_genomes/320153/MG1001.mbin.2/MG1001.mbin.2.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1001.mbin.7.fa to VMGC_db/cleaned_genomes/696853/MG1001.mbin.7/MG1001.mbin.7.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1001.mbin.9.fa to VMGC_db/cleaned_genomes/508744/MG1001.mbin.9/MG1001.mbin.9.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1001.sbin.11.fa to VMGC_db/cleaned_genomes/339874/MG1001.sbin.11/MG1001.sbin.11.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1002.mbin.1.fa to VMGC_db/cleaned_genomes/897926/MG1002.mbin.1/MG1002.mbin.1.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1002.mbin.11.fa to VMGC_db/cleaned_genomes/536396/MG1002.mbin.11/MG1002.mbin.11.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1002.mbin.12.fa to VMGC_db/cleaned_genomes/508744/MG1002.mbin.12/MG1002.mbin.12.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1002.mbin.3.fa to VMGC_db/cleaned_genomes/696853/MG1002.mbin.3/MG1002.mbin.3.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1002.mbin.5.fa to VMGC_db/cleaned_genomes/134035/MG1002.mbin.5/MG1002.mbin.5.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1002.mbin.6.fa to VMGC_db/cleaned_genomes/320153/MG1002.mbin.6/MG1002.mbin.6.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1002.mbin.9.fa to VMGC_db/cleaned_genomes/130451/MG1002.mbin.9/MG1002.mbin.9.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1002.sbin.16.fa to VMGC_db/cleaned_genomes/940775/MG1002.sbin.16/MG1002.sbin.16.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1002.sbin.5.fa to VMGC_db/cleaned_genomes/339874/MG1002.sbin.5/MG1002.sbin.5.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1002.sbin.9.fa to VMGC_db/cleaned_genomes/696853/MG1002.sbin.9/MG1002.sbin.9.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1003.mbin.6.fa to VMGC_db/cleaned_genomes/595185/MG1003.mbin.6/MG1003.mbin.6.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1003.sbin.1.fa to VMGC_db/cleaned_genomes/988598/MG1003.sbin.1/MG1003.sbin.1.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1003.sbin.5.fa to VMGC_db/cleaned_genomes/130451/MG1003.sbin.5/MG1003.sbin.5.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1004.mbin.2.fa to VMGC_db/cleaned_genomes/240891/MG1004.mbin.2/MG1004.mbin.2.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1005.mbin.2.fa to VMGC_db/cleaned_genomes/240891/MG1005.mbin.2/MG1005.mbin.2.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1008.mbin.2.fa to VMGC_db/cleaned_genomes/805810/MG1008.mbin.2/MG1008.mbin.2.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1008.mbin.3.fa to VMGC_db/cleaned_genomes/173875/MG1008.mbin.3/MG1008.mbin.3.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1008.mbin.7.fa to VMGC_db/cleaned_genomes/982633/MG1008.mbin.7/MG1008.mbin.7.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1008.mbin.8.fa to VMGC_db/cleaned_genomes/240891/MG1008.mbin.8/MG1008.mbin.8.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1009.mbin.7.fa to VMGC_db/cleaned_genomes/553789/MG1009.mbin.7/MG1009.mbin.7.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG1009.sbin.6.fa to VMGC_db/cleaned_genomes/553789/MG1009.sbin.6/MG1009.sbin.6.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG101.mbin.1.fa to VMGC_db/cleaned_genomes/536396/MG101.mbin.1/MG101.mbin.1.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG101.mbin.10.fa to VMGC_db/cleaned_genomes/696853/MG101.mbin.10/MG101.mbin.10.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG101.mbin.12.fa to VMGC_db/cleaned_genomes/897926/MG101.mbin.12/MG101.mbin.12.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG101.mbin.14.fa to VMGC_db/cleaned_genomes/674974/MG101.mbin.14/MG101.mbin.14.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG101.mbin.15.fa to VMGC_db/cleaned_genomes/941235/MG101.mbin.15/MG101.mbin.15.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG101.mbin.16.fa to VMGC_db/cleaned_genomes/187277/MG101.mbin.16/MG101.mbin.16.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG101.mbin.17.fa to VMGC_db/cleaned_genomes/937223/MG101.mbin.17/MG101.mbin.17.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG101.mbin.18.fa to VMGC_db/cleaned_genomes/109652/MG101.mbin.18/MG101.mbin.18.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG101.mbin.19.fa to VMGC_db/cleaned_genomes/653259/MG101.mbin.19/MG101.mbin.19.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG101.mbin.20.fa to VMGC_db/cleaned_genomes/927036/MG101.mbin.20/MG101.mbin.20.fna: No such file or directory
# mv: rename VMGC_orig_files/VMGC_prokaryote_MAGMG101.mbin.21.fa to VMGC_db/cleaned_genomes/285819/MG101.mbin.21/MG101.mbin.21.fna: No such file or directory

# %%
len(fastas)
# Out:
# 811

# %% [markdown]
# ### Select a few genomes for a test run

# %%
# !mkdir test_db

# %%
# !mv VMGC_db/cleaned_genomes test_db/

# %%
genome_names = []

for genome, row in genomes.iterrows():
    
    sp = row['species']
    if os.path.exists('test_db/cleaned_genomes/{}/{}'.format(sp, genome)):
        genome_names += [genome]

# %%
test_set = genomes.loc[genome_names]
test_set = test_set.merge(df.set_index('Genome_ID')[['Quality_score']], left_index=True, right_index=True)

# %%
#resetting representative genomes from test set

test_rep_genomes = test_set.sort_values('Quality_score', ascending=False).drop_duplicates('species').reset_index().set_index('species')['index'].to_dict()

test_set['representative'] = test_set['species'].map(test_rep_genomes)
test_set['genome_is_representative'] = (test_set.index == test_set['representative']).astype(int)
test_set = test_set.drop(columns='Quality_score')
test_set.index.name = 'genome'

# %%
test_set
# Out:
#                 species  representative  genome_is_representative
# genome
# MG100.sbin.5     897926    MG106.mbin.2                         0
# MG100.mbin.11    223646   MG100.mbin.11                         1
# MG100.mbin.2     339874  MG1030.mbin.15                         0
# MG100.mbin.5     447222   MG1063.mbin.8                         0
# MG100.mbin.1     109652   MG1035.mbin.3                         0
# ...                 ...             ...                       ...
# MG1070.mbin.31   332460    MG103.mbin.9                         0
# MG1070.mbin.26   956728  MG1069.mbin.26                         0
# MG1070.mbin.33   620611  MG1070.mbin.33                         1
# MG1070.mbin.38   460020  MG1038.sbin.18                         0
# MG1070.mbin.32   516615  MG1070.mbin.32                         1
#
# [811 rows x 3 columns]

# %%
test_set.to_csv('test_db/genomes.tsv', sep='\t')
