# %%
import gffutils

# %%
import os
import pathlib
#import re
import pandas as pd
from Bio import SeqIO
import numpy as np
import gffutils
from collections import Counter

# %% [markdown]
# ### Unzip db builds (if necessary):
#
#     tar -zxf nextflow_db.tar.gz
#     tar -zxf midasdb_localdb.tar.gz

# %% [markdown]
# ### Output of nextflow pipeline

# %%
my_db_path = '/wynton/protected/home/sirota/clairedubin/MIDAS3_nextflow/old/nextflow_db'

# %% [markdown]
# ### Output run generated Chunyu using original MIDAS scripts
#
# Original code here: https://github.com/czbiohub-sf/MIDAS/blob/master/tests/test_db.sh

# %%
correct_db_path = '/wynton/protected/home/sirota/clairedubin/MIDAS3_nextflow/testing/midasdb_localdb'

# %% [markdown]
# ### Comparing folders
#
# Mine is missing genomes.tsv, markers_models, and cleaned_imports because the nextflow pipeline doesn't require these input files to be stored within the database directory.

# %%
# !ls {my_db_path}
# Out:
# chunks	gene_annotations  markers  pangenomes  pangenomes_annotation

# %%
# !ls {correct_db_path}
# Out:
# chunks		 gene_annotations  markers	   pangenomes
# cleaned_imports  genomes.tsv	   markers_models  pangenomes_annotation

# %% [markdown]
# ### Get list of files in each database

# %%
db = 'nextflow_db'
my_db_files = []

for path, subdirs, files in os.walk(db):
    for name in files:
        
        if name == 'genomes.tsv' or 'cleaned_imports' in path:
            continue
        
        my_db_files += [os.path.join(path, name).replace(db+'/', '')]

# %%
db = 'midasdb_localdb'
correct_db_files = []

for path, subdirs, files in os.walk(db):
    for name in files:
        if '.log' in name: #ignore missing log files
            continue
        if name == 'genomes.tsv' or 'cleaned_imports' in path or 'markers_models' in path:
            continue
        correct_db_files += [os.path.join(path, name).replace(db+'/', '')]

# %% [markdown]
# ### Compare list of files generated by each database

# %%
not_matched = []

for f in correct_db_files:
    
    if f in my_db_files:
        continue
            
    file_only = f.split('/')[-1]
    
    if '.log' in f:
        continue
    
    potential_files = [i for i in my_db_files if i.split('/')[-1] == file_only]
    if len(potential_files) > 0:

        
        if '117086' in f:
            potential_files = [i for i in potential_files if '117086' in i]
        elif '117088' in f:
            potential_files = [i for i in potential_files if '117088' in i]
        
        print(f)
        print('possible matches:')
        for i in potential_files:
            print(i)
    
    else:
        print(f)
        print('no matches found')
    
    print()
    
    not_matched+=[f]
# Out:
# pangenomes/117088/clusters_95_info.tsv
# no matches found
#
# pangenomes/117088/genes_info.tsv
# no matches found
#
# pangenomes/117088/clusters_80_info.tsv
# no matches found
#
# pangenomes/117088/centroids.ffn
# no matches found
#
# pangenomes/117088/genes_annotated.tsv
# no matches found
#
# pangenomes/117088/clusters_85_info.tsv
# no matches found
#
# pangenomes/117088/clusters_75_info.tsv
# no matches found
#
# pangenomes/117088/clusters_90_info.tsv
# no matches found
#
# pangenomes/117088/clusters_99_info.tsv
# no matches found
#
# pangenomes/117088/annotation/clusters_90_annot.tsv
# no matches found
#
# pangenomes/117088/annotation/mefinder.tsv
# no matches found
#
# pangenomes/117088/annotation/resfinder.tsv
# no matches found
#
# pangenomes/117088/annotation/eggnog.tsv
# no matches found
#
# pangenomes/117088/annotation/clusters_85_annot.tsv
# no matches found
#
# pangenomes/117088/annotation/genomad_plasmid.tsv
# no matches found
#
# pangenomes/117088/annotation/clusters_80_annot.tsv
# no matches found
#
# pangenomes/117088/annotation/clusters_99_annot.tsv
# no matches found
#
# pangenomes/117088/annotation/clusters_75_annot.tsv
# no matches found
#
# pangenomes/117088/annotation/genomad_virus.tsv
# no matches found
#
# pangenomes/117088/annotation/clusters_95_annot.tsv
# no matches found
#
# pangenomes/117088/augment/centroid_99_lifted_to_GCA_007120565.1.tsv
# no matches found
#
# pangenomes/117088/augment/clusters_95_info.tsv
# no matches found
#
# pangenomes/117088/augment/clusters_75_info.tsv
# no matches found
#
# pangenomes/117088/augment/centroid_75_stacked_matrix.tsv
# no matches found
#
# pangenomes/117088/augment/clusters_90_info.tsv
# no matches found
#
# pangenomes/117088/augment/clusters_85_info.tsv
# no matches found
#
# pangenomes/117088/augment/clusters_99_info.tsv
# no matches found
#
# pangenomes/117088/augment/clusters_80_info.tsv
# no matches found
#
# pangenomes/117088/temp/uclust.75.txt
# no matches found
#
# pangenomes/117088/temp/centroids.80.ffn
# no matches found
#
# pangenomes/117088/temp/markers.map
# no matches found
#
# pangenomes/117088/temp/uclust.85.txt
# no matches found
#
# pangenomes/117088/temp/centroids.85.ffn
# no matches found
#
# pangenomes/117088/temp/mapfile
# no matches found
#
# pangenomes/117088/temp/uclust.80.txt
# no matches found
#
# pangenomes/117088/temp/uclust.95.txt
# no matches found
#
# pangenomes/117088/temp/genes_info.tsv
# no matches found
#
# pangenomes/117088/temp/centroids.90.ffn
# no matches found
#
# pangenomes/117088/temp/uclust.90.txt
# no matches found
#
# pangenomes/117088/temp/centroids.75.ffn
# no matches found
#
# pangenomes/117088/temp/centroids.95.ffn
# no matches found
#
# pangenomes/117088/temp/cdhit/genes.ffn
# possible matches:
# pangenomes/117088/genes.ffn
#
# pangenomes/117088/temp/cdhit/gene_info.txt
# no matches found
#
# pangenomes/117088/temp/cdhit/PIPELINE_SUCCESS
# no matches found
#
# pangenomes/117088/temp/cdhit/genes.len
# possible matches:
# pangenomes/117088/genes.len
# pangenomes/117088/temp/vsearch/genes.len
#
# pangenomes/117088/temp/cdhit/centroids.99.ffn
# possible matches:
# pangenomes/117088/temp/vsearch/centroids.99.ffn
#
# pangenomes/117088/temp/cdhit/step4_info/list_of_cdhit_genes
# no matches found
#
# pangenomes/117088/temp/cdhit/step4_info/cdhit_centroids.tsv
# no matches found
#
# pangenomes/117088/temp/cdhit/step4_info/cdhit_gene_centroid_mapping.tsv
# no matches found
#
# pangenomes/117088/temp/cdhit/step4_info/cdhit_centroids.ffn
# no matches found
#
# pangenomes/117088/temp/cdhit/step4_info/gene_info_cdhit.tsv
# no matches found
#
# pangenomes/117088/temp/cdhit/step4_info/gene_info_vsearch.tsv
# no matches found
#
# pangenomes/117088/temp/cdhit/step4_info/vsearch_centroids.ffn
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/cdhit_centroids_upper.ffn
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/vsearch_centroids_renamed.ffn
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/new_centroids.tsv
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/list_of_cdhit_centroids_by_tsv
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/list_of_cdhit_centroids_by_ffn
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/mapping.txt
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/cdhit_centroids.tsv
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/cdhit_centroids.ffn
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/vsearch_centroids.ffn
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/cdhit_centroids.ffn.clstr.tsv
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/cdhit_centroids.ffn.clstr
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/new_members.tsv
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/cdhit_centroids_c2.tsv
# no matches found
#
# pangenomes/117088/temp/cdhit/step3_cdhit/new_members_w_centroids.tsv
# no matches found
#
# pangenomes/117088/temp/vsearch/centroids.99.clean.ffn
# no matches found
#
# pangenomes/117088/temp/vsearch/genes.ffn
# possible matches:
# pangenomes/117088/genes.ffn
#
# pangenomes/117088/temp/vsearch/gene_info.txt
# no matches found
#
# pangenomes/117088/temp/vsearch/centroids.99.ambiguous.ffn
# no matches found
#
# pangenomes/117086/genes_info.tsv
# no matches found
#
# pangenomes/117086/clusters_90_info.tsv
# no matches found
#
# pangenomes/117086/genes_annotated.tsv
# no matches found
#
# pangenomes/117086/clusters_85_info.tsv
# no matches found
#
# pangenomes/117086/clusters_99_info.tsv
# no matches found
#
# pangenomes/117086/centroids.ffn
# no matches found
#
# pangenomes/117086/clusters_95_info.tsv
# no matches found
#
# pangenomes/117086/clusters_75_info.tsv
# no matches found
#
# pangenomes/117086/clusters_80_info.tsv
# no matches found
#
# pangenomes/117086/annotation/genomad_virus.tsv
# no matches found
#
# pangenomes/117086/annotation/mefinder.tsv
# no matches found
#
# pangenomes/117086/annotation/clusters_95_annot.tsv
# no matches found
#
# pangenomes/117086/annotation/clusters_90_annot.tsv
# no matches found
#
# pangenomes/117086/annotation/clusters_99_annot.tsv
# no matches found
#
# pangenomes/117086/annotation/clusters_80_annot.tsv
# no matches found
#
# pangenomes/117086/annotation/clusters_75_annot.tsv
# no matches found
#
# pangenomes/117086/annotation/resfinder.tsv
# no matches found
#
# pangenomes/117086/annotation/eggnog.tsv
# no matches found
#
# pangenomes/117086/annotation/clusters_85_annot.tsv
# no matches found
#
# pangenomes/117086/annotation/genomad_plasmid.tsv
# no matches found
#
# pangenomes/117086/temp/genes_info.tsv
# no matches found
#
# pangenomes/117086/temp/centroids.90.ffn
# no matches found
#
# pangenomes/117086/temp/mapfile
# no matches found
#
# pangenomes/117086/temp/uclust.95.txt
# no matches found
#
# pangenomes/117086/temp/centroids.95.ffn
# no matches found
#
# pangenomes/117086/temp/uclust.75.txt
# no matches found
#
# pangenomes/117086/temp/centroids.80.ffn
# no matches found
#
# pangenomes/117086/temp/uclust.85.txt
# no matches found
#
# pangenomes/117086/temp/markers.map
# no matches found
#
# pangenomes/117086/temp/centroids.75.ffn
# no matches found
#
# pangenomes/117086/temp/uclust.90.txt
# no matches found
#
# pangenomes/117086/temp/centroids.85.ffn
# no matches found
#
# pangenomes/117086/temp/uclust.80.txt
# no matches found
#
# pangenomes/117086/temp/cdhit/genes.ffn
# possible matches:
# pangenomes/117086/genes.ffn
#
# pangenomes/117086/temp/cdhit/genes.len
# possible matches:
# pangenomes/117086/genes.len
# pangenomes/117086/temp/vsearch/genes.len
#
# pangenomes/117086/temp/cdhit/centroids.99.ffn
# possible matches:
# pangenomes/117086/temp/vsearch/centroids.99.ffn
#
# pangenomes/117086/temp/cdhit/PIPELINE_SUCCESS
# no matches found
#
# pangenomes/117086/temp/cdhit/gene_info.txt
# no matches found
#
# pangenomes/117086/temp/cdhit/step4_info/cdhit_gene_centroid_mapping.tsv
# no matches found
#
# pangenomes/117086/temp/cdhit/step4_info/gene_info_vsearch.tsv
# no matches found
#
# pangenomes/117086/temp/cdhit/step4_info/cdhit_centroids.tsv
# no matches found
#
# pangenomes/117086/temp/cdhit/step4_info/gene_info_cdhit.tsv
# no matches found
#
# pangenomes/117086/temp/cdhit/step4_info/vsearch_centroids.ffn
# no matches found
#
# pangenomes/117086/temp/cdhit/step4_info/cdhit_centroids.ffn
# no matches found
#
# pangenomes/117086/temp/cdhit/step4_info/list_of_cdhit_genes
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/cdhit_centroids_c2.tsv
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/cdhit_centroids.ffn.clstr
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/new_members_w_centroids.tsv
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/new_centroids.tsv
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/vsearch_centroids.ffn
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/cdhit_centroids.tsv
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/list_of_cdhit_centroids_by_tsv
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/vsearch_centroids_renamed.ffn
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/list_of_cdhit_centroids_by_ffn
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/new_members.tsv
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/cdhit_centroids_upper.ffn
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/cdhit_centroids.ffn.clstr.tsv
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/cdhit_centroids.ffn
# no matches found
#
# pangenomes/117086/temp/cdhit/step3_cdhit/mapping.txt
# no matches found
#
# pangenomes/117086/temp/vsearch/genes.ffn
# possible matches:
# pangenomes/117086/genes.ffn
#
# pangenomes/117086/temp/vsearch/centroids.99.ambiguous.ffn
# no matches found
#
# pangenomes/117086/temp/vsearch/centroids.99.clean.ffn
# no matches found
#
# pangenomes/117086/temp/vsearch/gene_info.txt
# no matches found
#
# pangenomes/117086/augment/clusters_99_info.tsv
# no matches found
#
# pangenomes/117086/augment/clusters_80_info.tsv
# no matches found
#
# pangenomes/117086/augment/centroid_75_stacked_matrix.tsv
# no matches found
#
# pangenomes/117086/augment/centroid_99_lifted_to_GCA_900552055.1.tsv
# no matches found
#
# pangenomes/117086/augment/clusters_90_info.tsv
# no matches found
#
# pangenomes/117086/augment/clusters_95_info.tsv
# no matches found
#
# pangenomes/117086/augment/clusters_85_info.tsv
# no matches found
#
# pangenomes/117086/augment/clusters_75_info.tsv
# no matches found
#
# pangenomes_annotation/03_processed/117088/mefinder/GCA_007120565.1
# no matches found
#
# pangenomes_annotation/03_processed/117088/mefinder/GCA_007135585.1
# no matches found
#
# pangenomes_annotation/03_processed/117088/genomad_plasmid/GCA_007135585.1
# no matches found
#
# pangenomes_annotation/03_processed/117088/genomad_plasmid/GCA_007120565.1
# no matches found
#
# pangenomes_annotation/03_processed/117088/resfinder/GCA_007135585.1
# no matches found
#
# pangenomes_annotation/03_processed/117088/resfinder/GCA_007120565.1
# no matches found
#
# pangenomes_annotation/03_processed/117088/eggnog/GCA_007120565.1
# no matches found
#
# pangenomes_annotation/03_processed/117088/eggnog/GCA_007135585.1
# no matches found
#
# pangenomes_annotation/03_processed/117088/genomad_virus/GCA_007120565.1
# no matches found
#
# pangenomes_annotation/03_processed/117088/genomad_virus/GCA_007135585.1
# no matches found
#
# pangenomes_annotation/03_processed/117086/eggnog/GCA_900552055.1
# no matches found
#
# pangenomes_annotation/03_processed/117086/eggnog/GCF_900752885.1
# no matches found
#
# pangenomes_annotation/03_processed/117086/genomad_plasmid/GCA_900552055.1
# no matches found
#
# pangenomes_annotation/03_processed/117086/genomad_plasmid/GCF_900752885.1
# no matches found
#
# pangenomes_annotation/03_processed/117086/resfinder/GCA_900552055.1
# no matches found
#
# pangenomes_annotation/03_processed/117086/resfinder/GCF_900752885.1
# no matches found
#
# pangenomes_annotation/03_processed/117086/genomad_virus/GCA_900552055.1
# no matches found
#
# pangenomes_annotation/03_processed/117086/genomad_virus/GCF_900752885.1
# no matches found
#
# pangenomes_annotation/03_processed/117086/mefinder/GCA_900552055.1
# no matches found
#
# pangenomes_annotation/03_processed/117086/mefinder/GCF_900752885.1
# no matches found
#
# pangenomes_annotation/02_eggnog/117088/117088.emapper.hits
# no matches found
#
# pangenomes_annotation/02_eggnog/117088/117088.emapper.pfam
# no matches found
#
# pangenomes_annotation/02_eggnog/117088/117088.emapper.seed_orthologs
# no matches found
#
# pangenomes_annotation/02_eggnog/117088/117088.emapper.annotations
# no matches found
#
# pangenomes_annotation/02_eggnog/117086/117086.emapper.annotations
# no matches found
#
# pangenomes_annotation/02_eggnog/117086/117086.emapper.hits
# no matches found
#
# pangenomes_annotation/02_eggnog/117086/117086.emapper.pfam
# no matches found
#
# pangenomes_annotation/02_eggnog/117086/117086.emapper.seed_orthologs
# no matches found

# %% [markdown]
# ### Unmatched files:
#
#      'pangenomes/117086/genes.ffn' - can ignore, this is the same as nextflow_db/pangenomes/117086/vsearch/genes.ffn, just a different path
#
#      'pangenomes/117086/temp/vsearch/genes.len' - can ignore, this is the same as nextflow_db/pangenomes/117086/vsearch/genes.len, just a different path
#
#      'pangenomes/117086/temp/vsearch/genes.ffn' - can ignore, this is the same as nextflow_db/pangenomes/117086/vsearch/genes.ffn, just a different path

# %%
not_matched
# Out:
# ['pangenomes/117086/genes.ffn',
#  'pangenomes/117086/temp/vsearch/genes.len',
#  'pangenomes/117086/temp/vsearch/genes.ffn',
#  'pangenomes/117088/genes.ffn',
#  'pangenomes/117088/temp/vsearch/genes.len',
#  'pangenomes/117088/temp/vsearch/genes.ffn',
#  'pangenomes_annotation/01_mge/117088/GCA_007135585.1/resfinder_output/resfinder_blast/tmp/out_glycopeptide.xml']

# %%
#genes.len files are the same
# !diff <(sort midasdb_localdb/pangenomes/117086/temp/vsearch/genes.len) <(sort nextflow_db/pangenomes/117086/vsearch/genes.len)

#genes.ffn files are the same
# !diff <(sort midasdb_localdb/pangenomes/117086/temp/vsearch/genes.ffn) <(sort nextflow_db/pangenomes/117086/vsearch/genes.ffn)

#other genes.ffn files are the same
# !diff <(sort midasdb_localdb/pangenomes/117086/genes.ffn) <(sort nextflow_db/pangenomes/117086/vsearch/genes.ffn)

# %%
#genes.len files are the same
# !diff <(sort midasdb_localdb/pangenomes/117088/temp/vsearch/genes.len) <(sort nextflow_db/pangenomes/117088/vsearch/genes.len)

#genes.ffn files are the same
# !diff <(sort midasdb_localdb/pangenomes/117088/temp/vsearch/genes.ffn) <(sort nextflow_db/pangenomes/117088/vsearch/genes.ffn)

#other genes.ffn files are the same
# !diff <(sort midasdb_localdb/pangenomes/117088/genes.ffn) <(sort nextflow_db/pangenomes/117088/vsearch/genes.ffn)

# %% [markdown]
# ### Are the contents of each file the same?

# %%
#ignore lines with these words
diff_exclude = '" -I "'.join(['-I "clairedubin','pollard', #names in most paths
                        '^\#.*', #exclude comment lines  
                        'time', 'tm_sec', 'tm_min', 'tm_hour', 'tm_mday',
                        'tm_mon', 'tm_wday', 'tm_yday', 'Date', #timestamp stuff
                        'Database name', #path to databases (some aren't full paths)
                        '\<Statistics_',  #comments in resfinder outputs
                             
                             ])
diff_exclude += '"'

# %%
#these will cause diff to take a long time
binary_files = ['markers/phyeco/phyeco.fa.bwt',
               'markers/phyeco/phyeco.fa.sa']

# %%
different_contents = {}
same_contents = []
different_but_ok_files = []

for f in correct_db_files:
        
    if f in not_matched or f in binary_files:
        continue
        
    if 'temp' in f or 'tmp' in f:#skip intermediate files
        continue
        
    #recheck if contents are the same, excluding words specified above and sorting lines
    cmd = f"diff {diff_exclude} <(sort nextflow_db/{f}) <(sort midasdb_localdb/{f})"
    diff_out = !{cmd}
    
    if len(diff_out) == 0:
        same_contents += [f]
        continue
    
    different_contents[f] =  [f'nextflow_db/{f}', f'midasdb_localdb/{f}', diff_out]

# %%
len(same_contents), len(different_contents)
# Out:
# (330, 48)

# %% [markdown]
# ### Which subfolders have differing files?

# %%
subs = []

for i in different_contents.keys():
    
    subfolder = i.split('/')[0]
    subs += [subfolder]
    
Counter(subs)
# Out:
# Counter({'markers': 1, 'gene_annotations': 4, 'pangenomes_annotation': 43})

# %% [markdown]
# ### Compare differing files in gene_annotations directory
#
# These are the same - diff just can't handle the DB files

# %%
g = []
for i in different_contents.keys():
    if 'gene_annotations/' in i:
        print(i)
        g += [i]
# Out:
# gene_annotations/117086/GCF_900752885.1/GCF_900752885.1.gff.db
# gene_annotations/117086/GCA_900552055.1/GCA_900552055.1.gff.db
# gene_annotations/117088/GCA_007135585.1/GCA_007135585.1.gff.db
# gene_annotations/117088/GCA_007120565.1/GCA_007120565.1.gff.db

# %%
for i in g:

    test_gff = gffutils.interface.FeatureDB(f'nextflow_db/{i}')
    correct_gff = gffutils.interface.FeatureDB(f'midasdb_localdb/{i}')

    c = correct_gff.all_features()

    for i in test_gff.all_features():
        if i != next(c):
            print(i)

# %%
ignore_diffs = []
ignore_diffs += [i for i in different_contents.keys() if 'gene_annotations/' in i]

# %% [markdown]
# ### Compare differing files in markers directory
#
# Header files are just different because of the date/path in the header.

# %%
for i in different_contents.keys():
    if 'markers/' in i:
        print(i)
# Out:
# markers/phyeco/phyeco.fa.header

# %%
f = 'markers/phyeco/phyeco.fa'
cmd = f"diff {diff_exclude} <(sort nextflow_db/{f}) <(sort midasdb_localdb/{f})"
# !{cmd}

# %%
f = 'markers/phyeco/phyeco.fa.header'
cmd = f"diff {diff_exclude} <(sort nextflow_db/{f}) <(sort midasdb_localdb/{f})"
# !{cmd}
# Out:
# 7,9c7,9
# < 	tm_yday=27
# < 	tm_year=125
# < Database name=phyeco.fa
# ---
# > 	tm_yday=267
# > 	tm_year=124
# > Database name=/pollard/home/czhao/projects/MIDAS/tests/midasdb_localdb/markers/phyeco/phyeco.fa

# %%
ignore_diffs += ['markers/phyeco/phyeco.fa.header']

# %% [markdown]
# ## Compare differing files in pangenomes_annotation directory

# %%
for i in different_contents.keys():
    if 'pangenomes_annotation/' in i:
        print(i)
# Out:
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_nn_classification/GCF_900752885.1_nn_classification.tsv
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_nn_classification/GCF_900752885.1_nn_classification.npz
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_nn_classification/GCF_900752885.1_provirus_nn_classification.npz
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_marker_classification/GCF_900752885.1_features.npz
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_score_calibration/GCF_900752885.1_calibrated_aggregated_classification.tsv
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_score_calibration/GCF_900752885.1_calibrated_nn_classification.npz
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_score_calibration/GCF_900752885.1_calibrated_aggregated_classification.npz
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_score_calibration/GCF_900752885.1_calibrated_nn_classification.tsv
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_score_calibration/GCF_900752885.1_provirus_calibrated_nn_classification.npz
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_score_calibration/GCF_900752885.1_provirus_calibrated_marker_classification.npz
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_score_calibration/GCF_900752885.1_provirus_calibrated_aggregated_classification.npz
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_score_calibration/GCF_900752885.1_calibrated_marker_classification.npz
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_aggregated_classification/GCF_900752885.1_aggregated_classification.tsv
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_aggregated_classification/GCF_900752885.1_aggregated_classification.npz
# pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_aggregated_classification/GCF_900752885.1_provirus_aggregated_classification.npz
# pangenomes_annotation/01_mge/117086/GCA_900552055.1/genomad_output/GCA_900552055.1_score_calibration/GCA_900552055.1_calibrated_nn_classification.npz
# pangenomes_annotation/01_mge/117086/GCA_900552055.1/genomad_output/GCA_900552055.1_score_calibration/GCA_900552055.1_calibrated_aggregated_classification.npz
# pangenomes_annotation/01_mge/117086/GCA_900552055.1/genomad_output/GCA_900552055.1_score_calibration/GCA_900552055.1_provirus_calibrated_aggregated_classification.npz
# pangenomes_annotation/01_mge/117086/GCA_900552055.1/genomad_output/GCA_900552055.1_score_calibration/GCA_900552055.1_provirus_calibrated_nn_classification.npz
# pangenomes_annotation/01_mge/117086/GCA_900552055.1/genomad_output/GCA_900552055.1_marker_classification/GCA_900552055.1_features.npz
# pangenomes_annotation/01_mge/117086/GCA_900552055.1/genomad_output/GCA_900552055.1_aggregated_classification/GCA_900552055.1_provirus_aggregated_classification.npz
# pangenomes_annotation/01_mge/117086/GCA_900552055.1/genomad_output/GCA_900552055.1_aggregated_classification/GCA_900552055.1_aggregated_classification.npz
# pangenomes_annotation/01_mge/117086/GCA_900552055.1/genomad_output/GCA_900552055.1_nn_classification/GCA_900552055.1_nn_classification.tsv
# pangenomes_annotation/01_mge/117086/GCA_900552055.1/genomad_output/GCA_900552055.1_nn_classification/GCA_900552055.1_nn_classification.npz
# pangenomes_annotation/01_mge/117086/GCA_900552055.1/genomad_output/GCA_900552055.1_nn_classification/GCA_900552055.1_provirus_nn_classification.npz
# pangenomes_annotation/01_mge/117088/GCA_007135585.1/genomad_output/GCA_007135585.1_nn_classification/GCA_007135585.1_nn_classification.npz
# pangenomes_annotation/01_mge/117088/GCA_007135585.1/genomad_output/GCA_007135585.1_nn_classification/GCA_007135585.1_nn_classification.tsv
# pangenomes_annotation/01_mge/117088/GCA_007135585.1/genomad_output/GCA_007135585.1_aggregated_classification/GCA_007135585.1_aggregated_classification.npz
# pangenomes_annotation/01_mge/117088/GCA_007135585.1/genomad_output/GCA_007135585.1_score_calibration/GCA_007135585.1_calibrated_aggregated_classification.tsv
# pangenomes_annotation/01_mge/117088/GCA_007135585.1/genomad_output/GCA_007135585.1_score_calibration/GCA_007135585.1_calibrated_aggregated_classification.npz
# pangenomes_annotation/01_mge/117088/GCA_007135585.1/genomad_output/GCA_007135585.1_score_calibration/GCA_007135585.1_calibrated_nn_classification.npz
# pangenomes_annotation/01_mge/117088/GCA_007135585.1/genomad_output/GCA_007135585.1_score_calibration/GCA_007135585.1_calibrated_marker_classification.npz
# pangenomes_annotation/01_mge/117088/GCA_007135585.1/genomad_output/GCA_007135585.1_marker_classification/GCA_007135585.1_features.npz
# pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_aggregated_classification/GCA_007120565.1_aggregated_classification.npz
# pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_aggregated_classification/GCA_007120565.1_aggregated_classification.tsv
# pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_nn_classification/GCA_007120565.1_nn_classification.tsv
# pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_nn_classification/GCA_007120565.1_nn_classification.npz
# pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_score_calibration/GCA_007120565.1_calibrated_marker_classification.npz
# pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_score_calibration/GCA_007120565.1_calibrated_nn_classification.npz
# pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_score_calibration/GCA_007120565.1_calibrated_nn_classification.tsv
# pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_score_calibration/GCA_007120565.1_calibrated_aggregated_classification.tsv
# pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_score_calibration/GCA_007120565.1_calibrated_aggregated_classification.npz
# pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_marker_classification/GCA_007120565.1_features.npz

# %% [markdown]
# ### Genomad outputs
#
# TSVs and .npz files are the same, except for a <0.001 rounding difference in a few scores.

# %%
genomad_tsvs = [i for i in different_contents.keys() if 'genomad_output' in i and i.endswith('.tsv')]
genomad_tsvs
# Out:
# ['pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_nn_classification/GCF_900752885.1_nn_classification.tsv',
#  'pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_score_calibration/GCF_900752885.1_calibrated_aggregated_classification.tsv',
#  'pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_score_calibration/GCF_900752885.1_calibrated_nn_classification.tsv',
#  'pangenomes_annotation/01_mge/117086/GCF_900752885.1/genomad_output/GCF_900752885.1_aggregated_classification/GCF_900752885.1_aggregated_classification.tsv',
#  'pangenomes_annotation/01_mge/117086/GCA_900552055.1/genomad_output/GCA_900552055.1_nn_classification/GCA_900552055.1_nn_classification.tsv',
#  'pangenomes_annotation/01_mge/117088/GCA_007135585.1/genomad_output/GCA_007135585.1_nn_classification/GCA_007135585.1_nn_classification.tsv',
#  'pangenomes_annotation/01_mge/117088/GCA_007135585.1/genomad_output/GCA_007135585.1_score_calibration/GCA_007135585.1_calibrated_aggregated_classification.tsv',
#  'pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_aggregated_classification/GCA_007120565.1_aggregated_classification.tsv',
#  'pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_nn_classification/GCA_007120565.1_nn_classification.tsv',
#  'pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_score_calibration/GCA_007120565.1_calibrated_nn_classification.tsv',
#  'pangenomes_annotation/01_mge/117088/GCA_007120565.1/genomad_output/GCA_007120565.1_score_calibration/GCA_007120565.1_calibrated_aggregated_classification.tsv']

# %%
for f in genomad_tsvs:

    df1 = pd.read_csv(f'nextflow_db/{f}', sep='\t', index_col=0)
    df2 = pd.read_csv(f'midasdb_localdb/{f}', sep='\t', index_col=0)


    for gene, row1 in df1.iterrows():

        row2 = df2.loc[gene]
        if row1.equals(row2):
            continue

        #check if it's +/- 0.0001 difference
        elif abs(row1-row2).sum() <= 0.001:
            continue

        else:
            print(gene)
            print(row1.values)
            print(row2.values)
            print(abs(row1-row2).sum())
            print()

# %%
npz_files = []

for f, (test_path, correct_path, diff_out) in different_contents.items():

    if '.npz' in f and 'genomad' in f:
        npz_files += [(test_path, correct_path)]
        continue

for (f1_path, f2_path) in npz_files:
    
    f1 = np.load(f1_path)
    f2 = np.load(f2_path)
    for i in f1:

        if (f1[i] == f2[i]).all():
            continue

        else:
            diffs = np.where(abs(f1[i] - f2[i]) > 0.001)
            if len(diffs) != 0:
                print(diffs)
# Out:
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))

# %%
[i for i in different_contents.keys() if 'pangenomes_annotation/' in i and 'genomad' in i and not ('.npz' in i or '.tsv' in i)]
# Out:
# []

# %%
ignore_diffs += [i for i in different_contents.keys() if 'pangenomes_annotation/' in i and 'genomad' in i and ('.npz' in i or '.tsv' in i)]

# %%
[i for i in different_contents.keys() if i not in ignore_diffs]
# Out:
# []
